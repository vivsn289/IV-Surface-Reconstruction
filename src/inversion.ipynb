# %%
import pandas as pd
import matplotlib.pyplot as plt

PATH = "/home/harshil/IV-Surface-Reconstruction/src/data/spy_options_2010_2023_eod.csv"

# %%
data = pd.read_csv(PATH)
data.describe()
# Out:
#          Unnamed: 0       level_0  [QUOTE_UNIXTIME]  [QUOTE_TIME_HOURS]  \
# count  4.195810e+06  4.195810e+06      4.195810e+06           4195810.0
# mean   2.097904e+06  2.168731e+04      1.569672e+09                16.0
# std    1.211226e+06  1.744607e+04      1.149001e+08                 0.0
# min    0.000000e+00  0.000000e+00      1.262639e+09                16.0
# 25%    1.048952e+06  6.405000e+03      1.536782e+09                16.0
# 50%    2.097904e+06  1.722300e+04      1.605215e+09                16.0
# 75%    3.146857e+06  3.464400e+04      1.648757e+09                16.0
# max    4.195809e+06  7.156100e+04      1.703884e+09                16.0
#
#        [UNDERLYING_LAST]  [EXPIRE_UNIX]         [DTE]     [C_DELTA]  \
# count       4.195810e+06   4.195810e+06  4.195810e+06  4.195810e+06
# mean        3.308608e+02   1.585241e+09  1.801955e+02  5.946907e-01
# std         1.057264e+02   1.150368e+08  2.117639e+02  3.225268e-01
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  level_0  [QUOTE_UNIXTIME]  [QUOTE_READTIME] [QUOTE_DATE]  \
# 0           0        0        1664827200  2022-10-03 16:00   2022-10-03
# 1           1        1        1664827200  2022-10-03 16:00   2022-10-03
# 2           2        2        1664827200  2022-10-03 16:00   2022-10-03
# 3           3        3        1664827200  2022-10-03 16:00   2022-10-03
# 4           4        4        1664827200  2022-10-03 16:00   2022-10-03
#
#    [QUOTE_TIME_HOURS]  [UNDERLYING_LAST] [EXPIRE_DATE]  [EXPIRE_UNIX]  [DTE]  \
# 0                16.0             366.62    2022-10-03     1664827200    0.0
# 1                16.0             366.62    2022-10-03     1664827200    0.0
# 2                16.0             366.62    2022-10-03     1664827200    0.0
# 3                16.0             366.62    2022-10-03     1664827200    0.0
# 4                16.0             366.62    2022-10-03     1664827200    0.0
#
# ...

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'level_0', '[QUOTE_UNIXTIME]', '[QUOTE_READTIME]',
#        '[QUOTE_DATE]', '[QUOTE_TIME_HOURS]', '[UNDERLYING_LAST]',
#        '[EXPIRE_DATE]', '[EXPIRE_UNIX]', '[DTE]', '[C_DELTA]', '[C_GAMMA]',
#        '[C_VEGA]', '[C_THETA]', '[C_RHO]', '[C_IV]', '[C_VOLUME]', '[C_LAST]',
#        '[C_SIZE]', '[C_BID]', '[C_ASK]', '[STRIKE]', '[P_BID]', '[P_ASK]',
#        '[P_SIZE]', '[P_LAST]', '[P_DELTA]', '[P_GAMMA]', '[P_VEGA]',
#        '[P_THETA]', '[P_RHO]', '[P_IV]', '[P_VOLUME]', '[STRIKE_DISTANCE]',
#        '[STRIKE_DISTANCE_PCT]'],
#       dtype='object')

# %%
import json

with open("strings.json") as f:
    d = json.load(f)
    print(d)
# Out:
#   Cell In[2], line 8
#     break
#     ^
# SyntaxError: 'break' outside loop
